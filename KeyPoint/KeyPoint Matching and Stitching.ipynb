# %% [markdown]
# # EE596 - Homework 3 Report
# ###### Prepared by Paul Adams

# %% [markdown]
# # Part 1. Interest Operators

# %% [markdown]
# ## Image a1

# %%
names = glob(join("im.out", "a1*.jpg"))
im = [imread(name) for name in names]
si.show(im, names)

# %% [markdown]
# \pagebreak

# %% [markdown]
# ## Image a2

# %%
names = glob(join("im.out", "a2*.jpg"))
im = [imread(name) for name in names]
si.show(im, names)

# %% [markdown]
# \pagebreak

# %% [markdown]
# ## Image b1

# %%
names = glob(join("im.out", "b1*.jpg"))
im = [imread(name) for name in names]
si.show(im, names)

# %% [markdown]
# \pagebreak

# %% [markdown]
# ## Image b2

# %%
names = glob(join("im.out", "b2*.jpg"))
im = [imread(name) for name in names]
si.show(im, names)

# %% [markdown]
# \pagebreak

# %% [markdown]
# ## Image capri

# %%
names = glob(join("im.out", "capri*.jpg"))
im = [imread(name) for name in names]
si.show(im, names)

# %%
# %matplotlib inline
from matplotlib.pyplot import imread
from glob import glob
from os.path import join, splitext, split
import sys
sys.path.append('/home/adamspr/ee596/MachineVision')
from ScreenImage import ScreenImage
si = ScreenImage()

# %% [markdown]
# # Part 2: Matching Descriptors and Computing Homography
